# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('scores.csv')
df
# Out:
#                                           description    score
# 0                                    BoW + TFIDF + NB  0.78669
# 1                         BoW + TFIDF + SGDClassifier  0.79190
# 2                                   BoG + TFIDF + SVM  0.79221
# 3                         BoW + TFIDF + NB + Stemming  0.78976
# 4                               BoW + TFIDF + XGBoost  0.76987
# 5                    BoW + TFIDF + LogisticRegression  0.78608
# 6                           Glove (100dim) + Only CNN  0.57033
# 7                         Glove (100dim) + CNN + LSTM  0.76432
# 8                               Glove (100dim) + LSTM  0.79528
# 9                  Glove (50dim) + Bidirectional LSTM  0.80478
# 10                Glove (100dim) + Bidirectional LSTM  0.81397
# 11  Glove (100dim) + Bidirectional LSTM + Keywords...  0.80968
# 12                       BERT (without cleaning text)  0.83389
# 13                       BERT + Cleaning + cut length  0.83726
# 14                BERT + Cleaning + Keywords included  0.82807

# %%
# https://seaborn.pydata.org/generated/seaborn.barplot.html
g = sns.barplot(x=df['score'], y=df['description'], orient='h')
g.set_title("Métodos por orden de pruebas", fontsize=18)
g.set_xlabel("Score", fontsize=12)
g.set_ylabel("Descripción del método probado", fontsize=12)
# Out:
# Text(0, 0.5, 'Descripción del método probado')

# %%
by_score = df.sort_values('score',ascending=False)
by_score
# Out:
#                                           description    score
# 13                       BERT + Cleaning + cut length  0.83726
# 12                       BERT (without cleaning text)  0.83389
# 14                BERT + Cleaning + Keywords included  0.82807
# 10                Glove (100dim) + Bidirectional LSTM  0.81397
# 11  Glove (100dim) + Bidirectional LSTM + Keywords...  0.80968
# 9                  Glove (50dim) + Bidirectional LSTM  0.80478
# 8                               Glove (100dim) + LSTM  0.79528
# 2                                   BoG + TFIDF + SVM  0.79221
# 1                         BoW + TFIDF + SGDClassifier  0.79190
# 3                         BoW + TFIDF + NB + Stemming  0.78976
# 0                                    BoW + TFIDF + NB  0.78669
# 5                    BoW + TFIDF + LogisticRegression  0.78608
# 4                               BoW + TFIDF + XGBoost  0.76987
# 7                         Glove (100dim) + CNN + LSTM  0.76432
# 6                           Glove (100dim) + Only CNN  0.57033

# %%
# https://seaborn.pydata.org/generated/seaborn.barplot.html
g = sns.barplot(x=by_score['score'], y=by_score['description'], orient='h')
g.set_title("Métodos por mayor a menor según su puntaje", fontsize=15)
g.set_xlabel("Descripción del método probado", fontsize=12)
g.set_ylabel("Score", fontsize=12)
# Out:
# Text(0, 0.5, 'Score')
